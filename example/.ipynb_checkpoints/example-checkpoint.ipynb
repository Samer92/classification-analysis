# %%
# This code to link colab to a drive account
from google.colab import drive
drive.mount('/content/drive/')

import os
os.chdir('/content/drive/My Drive/Pytorch/pytorch vision classifier')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from classification_analysis.classification_analysis import ClassificationAnalysis
from sklearn.model_selection import train_test_split
from sklearn import datasets, metrics
from sklearn.svm import SVC

import matplotlib.pyplot as plt
import pickle as pk

from pprint import pprint

# %% [markdown]
# <h2>Binary Classification </h2>

# %%
# Prepare dataset
diabetes = datasets.load_breast_cancer()
X = diabetes.data
y = diabetes.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Feed SVM classifier
classifier = SVC(C=1.0, kernel='rbf', max_iter=-1)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9210526315789473

# %%
# plot confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
ax = plt.subplot(1,2,1)
ClassificationAnalysis.plot_confusion_matrix(confusion_matrix, list(diabetes.target_names), ax)

# %%
# plot confusion table sample
ax = plt.subplot(1,2,1)
ClassificationAnalysis.plot_confusion_table_sample(ax)

# %% [markdown]
# <h2>Multiclass Classification </h2>

# %%
# Prepare dataset
digits = datasets.load_digits()
X = digits.data
y = digits.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Feed SVM classifier
classifier = SVC(C=1.0, kernel='rbf', max_iter=-1)
classifier.fit(X_train, y_train)

y_pred = classifier.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9916666666666667

# %%
# plot confusion matrix
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
ax = plt.subplot(1,2,1)
ClassificationAnalysis.plot_confusion_matrix(confusion_matrix, list(diabetes.target_names), ax)

# %% [markdown]
# <h2>General Functions </h2>

# %%
# Steps Timing
with open('steps_timing.pkl', 'rb') as f:
  steps_timing = pk.load(f)

pprint(steps_timing)
# Out:
# {'backward': [0.000946,
#               0.000526,
#               0.000481,
#               0.002628,
#               0.001772,
#               0.001096,
#               0.000719,
#               0.001165,
#               0.000606,
#               0.000647],
#  'd_load': [],
#  'd_transfer': [0.001719,
#                 0.001868,
#                 0.001635,
#                 0.001331,
#                 0.002706,
#                 0.002587,
#                 0.001641,
#                 0.001542,
#                 0.001381,
#                 0.001378],
#  'forward': [0.022014,
#              0.020824,
#              0.020791,
#              0.020875,
#              0.022043,
#              0.02185,
#              0.023757,
#              0.020773,
#              0.0208,
#              0.02162],
#  'loss': [0.000431,
#           0.000205,
#           0.000193,
#           0.000806,
#           0.000211,
#           0.00016,
#           0.000253,
#           0.000233,
# ...

# %%
ClassificationAnalysis.steps_timing_visualization(steps_timing)

# %%
# Line plot
with open('acc_scores.pkl', 'rb') as f:
  acc_scores = pk.load(f)

pprint(acc_scores)
# Out:
# {'train_acc': [0.568,
#                0.606,
#                0.738,
#                0.77,
#                0.795,
#                0.801,
#                0.804,
#                0.801,
#                0.801,
#                0.801],
#  'val_acc': [0.65, 0.725, 0.838, 0.85, 0.85, 0.862, 0.85, 0.85, 0.85, 0.85]}

# %%
ClassificationAnalysis.line_plot(acc_scores['train_acc'], acc_scores['val_acc'], 'Accuracy')
# Out:
# Training Accuracy Min: 0.568, Max: 0.804 in epoch 6, Current: 0.801
# Validation Accuracy Min: 0.650, Max: 0.862 in epoch 5, Current: 0.850

# %%
# show overall metrics
with open('overall_metrics.pkl', 'rb') as f:
  overall_metrics = pk.load(f)

pprint(overall_metrics)
# Out:
# {'Accuracy': 0.862,
#  'Cohen_Kappa': 0.726,
#  'F1_score': 0.862,
#  'Precision': 0.867,
#  'Recall': 0.864,
#  'Specificity': 0.864}

# %%
ClassificationAnalysis.show_overall_metrics(overall_metrics)

# %%
# show overall metrics
with open('classes_metrics.pkl', 'rb') as f:
  classes_metrics = pk.load(f)

pprint(classes_metrics)
# Out:
# {'F1_score': array([0.857, 0.842]),
#  'Precision': array([0.8  , 0.914]),
#  'Recall': array([0.923, 0.78 ]),
#  'Specificity': array([0.78 , 0.923])}

# %%
ClassificationAnalysis.show_classes_metrics(classes_metrics, list(diabetes.target_names))

# %%
# show overall metrics
with open('roc.pkl', 'rb') as f:
  roc = pk.load(f)

pprint(roc)
# Out:
# {'fpr': array([0.   , 0.   , 0.   , 0.051, 0.051, 0.077, 0.077, 0.103, 0.103,
#        0.205, 0.205, 0.282, 0.282, 0.308, 0.308, 0.333, 0.333, 0.385,
#        0.385, 0.897, 0.897, 1.   ]),
#  'roc_auc': 0.922,
#  'tpr': array([0.   , 0.024, 0.61 , 0.61 , 0.732, 0.732, 0.805, 0.805, 0.829,
#        0.829, 0.878, 0.878, 0.902, 0.902, 0.927, 0.927, 0.951, 0.951,
#        0.976, 0.976, 1.   , 1.   ])}

# %%
ClassificationAnalysis.show_roc_curve(2, roc['fpr'], roc['tpr'], roc['roc_auc'])
